# %% [markdown]
# <table align="center">
#   <!-- ASSTIA link -->
#   <td align="center">
#     <a target="_blank" href="https://github.com/UMJI-SSTIA">
#       <img src="../images/SSTIA_logo.png" width="110px" height="70px" style="padding-bottom:5px;" />
#       Visit SSTIA
#     </a>
#   </td>
#
#   <!-- Google Colab link -->
#   <td align="center">
#     <a target="_blank" href="https://colab.research.google.com/github/UMJI-SSTIA/Python-Workshop-2026/blob/main/workshop/chinese/Part1_Intro_cn.ipynb">
#       <img src="https://i.ibb.co/2P3SLwK/colab.png" width="110px" height="70px" style="padding-bottom:5px;" />
#       Run in Google Colab
#     </a>
#   </td>
#
#   <!-- GitHub source link -->
#   <td align="center">
#     <a target="_blank" href="https://github.com/UMJI-SSTIA/Python-Workshop-2026/blob/main/workshop/chinese/Part1_Intro_cn.ipynb">
#       <img src="https://i.ibb.co/xfJbPmL/github.png" width="70px" height="70px" style="padding-bottom:5px;" />
#       View Source on GitHub
#     </a>
#   </td>
# </table>

# %% [markdown]
# ## 2026 SSTIA Python Workshop

# %% [markdown]
# ## 第 1 部分：Python 入门 —— Python 基础语法

# %% [markdown]
# ### 1.0 环境测试

# %% [markdown]
# 如果你点击下方的执行单元格按钮并成功打印内容，则说明你的环境配置正确。

# %%
import random
import time

print("Hello World")

# %% [markdown]
# Python 是世界上最流行的语言，它拥有丰富的开发工具和框架，以及极具可读性的编码风格。如果你正在构建一个对性能要求不是特别严苛的项目，Python 可能是最佳选择之一！此外，它也是 AI 开发和深度学习领域应用最广泛的语言。所以 Python 非常值得学习。那么……让我们开始吧！

# %% [markdown]
# ### 1.1 **Python —— 一门具有高可读性的语言**

# %% [markdown]
# 让我们先想象一下，我们想要制作一个“数字炸弹”游戏。这是一个简单的游戏：用户猜一个数字，程序根据猜测给出“大了”或“小了”的提示，直到猜中为止。首先，我们写一段**伪代码**来实现这个算法，随机答案范围为 1 到 100。

# %% [markdown]
# ```py
# secret_number = randint(1,100)
#
# user_guess = input("Please enter a number: ")
#
# while user_guess != secret_number:
#     if secret_number > user_guess:
#         print("Incorrect. The answer is larger")
#     if secret_number < user_guess:
#         print("Incorrect. The answer is smaller")
#     # 进行新的猜测
#     user_guess = input("Please enter a number: ")
#
# print("Correct")
# ```

# %% [markdown]
# 而一个真实的 Python 实现看起来是这样的：

# %%
secret_number = random.randint(1,100)

user_guess = int(input("Please enter a number: "))

while user_guess != secret_number:
    if secret_number > user_guess:
        print("Incorrect. The answer is larger")
    if secret_number < user_guess:
        print("Incorrect. The answer is smaller")
    # make a new guess
    user_guess = int(input("Please enter a number: "))

print("Correct")

# %% [markdown]
# 请注意这里的区别。为了将伪代码转换为有效的 Python 代码，我只是添加了 `random.` 前缀（表示该函数来自 `random` 库）以及 `int()` 函数（将输入的字符串转换为整数）。
#
# 这充分展示了 Python 语言的简洁性。

# %% [markdown]
# 然而，虽然 Python 的语法相当简单，但这并不意味着你可以随心所欲地编写代码（虽然有时语法正确，但不符合规范）。以下是一些需要注意的事项，特别是对于那些从其他语言转过来的开发者。

# %%
## Do this
sample_condition = True
if sample_condition:
    print("Use snake_case for variable name and pay attention to indentation here")

## Don't do this
# sampleCondition = True
# if sampleCondition:
# print("This is a bad variable name and invalid indentation")


## Do this
long_calculation = 100 + 200 + 300 \
    + 400 + 500
long_message = \
    "You don't need to add ';' for each line of code," \
    "but you need to pay attention when writing" \
    "a single code that has multiple lines"
# Or this
long_message = (
    "You don't need to add ';' for each line of code,"
    "but you need to pay attention when writing"
    "a single code that has multiple lines"
)
print(f"This is a long_message: {long_message}")

## Don't do this
# long_calculation = 100 + 200 + 300
#     + 400 + 500
# long_message =
#     "You don't need to add ';' for each line of code,"
#     "but you need to pay attention when writing"
#     "a single code that has multiple lines"
    
# print(f"This is a long_message: {long_message}")

# %% [markdown]
# ### 1.2 **数据类型**

# %% [markdown]
# 以下是 Python 的主要基础数据类型：
#
# - 数字 (Numbers): `int` (整型), `float` (浮点型), `complex` (复数)
# - 布尔值 (Booleans): `bool`
# - 字符串 (Strings): `str`
#
# 基本上就这些！（虽然还有一个字节类型 `bytes`，但你可能不会经常用到它）。
#
# 另外，一个定义：**字面量 (literal)** 是指一种简洁且“直接”的数值书写方式，例如 `558`, `2.6`, `"hello"`, `True`。

# %%
print(f"42 is a {type(42)}")
print(f"3.14 is a {type(3.14)}")
print(f"3.2e-10 is a {type(3.2e-10)}")
print(f"1+2j is a {type(1+2j)}")
print(f"True is a {type(True)}")
print(f'"Hello" is a {type("Hello")}')
print(f"'''Is Python that easy?''' is a {type('''Is Python that easy?''')}")

# %% [markdown]
# ### 1.3 **Python 数学运算符表**
#
# #### Python 数学运算符
#
# | 运算符 | 名称 | 描述 | 示例 | 结果 |
# |----------|------|-------------|---------|--------|
# | `+` | 加法 | 两个数相加 | `5 + 3` | `8` |
# | `-` | 减法 | 左操作数减去右操作数 | `10 - 4` | `6` |
# | `*` | 乘法 | 两个数相乘 | `7 * 6` | `42` |
# | `/` | 除法 | 左操作数除以右操作数（浮点结果） | `15 / 4` | `3.75` |
# | `//` | 整除 | 除法并向下取整到最近的整数 | `15 // 4` | `3` |
# | `%` | 取模 | 返回除法的余数 | `15 % 4` | `3` |
# | `**` | 幂运算 | 左操作数的右操作数次幂 | `2 ** 3` | `8` |
# | `=` | 赋值 | 将值赋给变量 | `x = 5` | `x = 5` |
#
# #### 复合赋值运算符
#
# | 运算符 | 等价于 | 示例 |
# |----------|--------------|---------|
# | `+=` | `x = x + y` | `x += 3` |
# | `-=` | `x = x - y` | `x -= 2` |
# | `*=` | `x = x * y` | `x *= 4` |
# | `/=` | `x = x / y` | `x /= 2` |
# | `//=` | `x = x // y` | `x //= 3` |
# | `%=` | `x = x % y` | `x %= 5` |
# | `**=` | `x = x ** y` | `x **= 2` |
#
# #### 比较运算符 (返回布尔值)
#
# | 运算符 | 名称 | 示例 | 结果 |
# |----------|------|---------|--------|
# | `==` | 等于 | `5 == 5` | `True` |
# | `!=` | 不等于 | `5 != 3` | `True` |
# | `>` | 大于 | `7 > 3` | `True` |
# | `<` | 小于 | `7 < 3` | `False` |
# | `>=` | 大于或等于 | `7 >= 7` | `True` |
# | `<=` | 小于或等于 | `5 <= 3` | `False` |

# %% [markdown]
# ### 1.4 **条件与循环**

# %% [markdown]
# #### 条件语句
#
# 条件语句非常容易理解，请尝试完成标注有 "TODO" 符号的单元格：

# %%
# Basic if statement

age = 24
## TODO: add a condition that indentify an adult using "if" keyword
print("You are an adult")

# %%
# if-else statement

temperature = 25
## TODO: Add a condition that print hot when temperature is above 30 degrees
## TODO: use "if" keyword here
print("It's hot outside")
## TODO: use "else" keyword here
print("It's not too hot")

# %%
# Multiple conditions with "elif" keyword

score = 85
## TODO: grading the score, 90~100 is A, 80~89 is B, 70 ~ 79 is C, below 70 is F
## TODO:
grade = "A"
## TODO:
grade = "B"
## TODO:
grade = "C"
## TODO:
grade = "F"
print(f"Grade: {grade}")

# %%
# Ternary Operator

## Ternary operator is just a short version of if-else
age = 20
status = "Adult" if age >= 18 else "Minor"

## TODO: using ternary operator print hot when temperature is above 30 degrees

temperature = 25
## TODO: 
print("It's hot outside")
print("It's not too hot")

# %% [markdown]
# #### Python 中的循环
#
# 在 Python 中，循环主要是 `for` 循环或 `while` 循环。`for` 循环可以配合 `range()` 函数像 Matlab 一样进行向量化操作：

# %%
# Basic for loop
for i in range(5):  # 0 to 4
    print(i)

# for loop with range parameters
for i in range(1, 6):  # 1 to 5
    print(i)

# for loop with step
for i in range(0, 10, 2):  # 0, 2, 4, 6, 8
    print(i)

## TODO: write a for loop print 5,4,3,2,1


# Iterating through a list （list is just array in Python)
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)

# Iterating with index
for index, fruit in enumerate(fruits):
    print(f"{index}: {fruit}")

# %%
# Basic while loop
count = 0
while count < 5:
    print(count)
    count += 1

# While loop with user input
password = ""
while password != "secret":
    password = input("Enter password: ")
print("Access granted!")

# Infinite loop with break
while True:
    user_input = input("Enter 'quit' to exit: ")
    if user_input == "quit":
        break

# %%
# Loop Control Statements

# Break out of loop
for num in range(10):
    if num == 5:
        break
    print(num)  # Prints 0,1,2,3,4

# continue Statement
# Skip current iteration
for num in range(5):
    if num == 2:
        continue  # Skip number 2
    print(num)  # Prints 0,1,3,4

# pass Statement
# Placeholder statement
for num in range(5):
    if num % 2 == 0:
        pass  # Do nothing, but need something here
    else:
        print(f"Odd: {num}")

# else in loop
# else executes when loop completes normally (no break)
for num in range(5):
    print(num)
else:
    print("Loop completed successfully")

# else doesn't execute when break is used
for num in range(5):
    if num == 3:
        break
    print(num)
else:
    print("This won't print")

# %% [markdown]
# 以上就是 Python 中的条件和循环。为了进行简单的练习，让我们尝试实现一个更高级版本的“数字炸弹”游戏：如果玩家猜测次数过多，将会输掉游戏。

# %%
secret_number = random.randint(1, 100)
max_guess = 5

user_guess = int(input("Please enter a number: "))

## TODO: write the number bomb game with "if" statement and "while" loop

# %% [markdown]
# ### 1.5 **Python 中的容器**

# %% [markdown]
# 在 Python 中，容器是用于存放其他对象的对象。最常见的内置容器包括列表 (List)、元组 (Tuple)、字典 (Dictionary) 和集合 (Set)。让我们通过示例逐一探索。

# %% [markdown]
# #### 1.5.1 列表 (Lists) —— 可变有序集合
# 列表是有序的、可更改的，并且允许重复元素。如果你有 C++ 基础，Python 中的 `list` 并不等同于 C++ 中的 `std::list`，而更像是一个动态数组（如 `std::vector`）。列表在内存中是线性存储的。

# %%
# Creating a list
fruits = ["apple", "banana", "cherry"]
numbers = [1, 2, 3, 4, 5]
mixed = ["text", 42, 3.14, True]

# Accessing elements
print(fruits[0])     # "apple" - first element
print(fruits[-1])    # "cherry" - last element

# Modifying lists
fruits.append("orange")      # Add to end
fruits.insert(1, "mango")    # Insert at position
fruits[2] = "blueberry"      # Change element
fruits.remove("banana")      # Remove specific item
popped = fruits.pop()        # Remove and return last item

# Slicing
print(numbers[1:3])   # [2, 3] - elements 1 to 2
print(numbers[:3])    # [1, 2, 3] - first 3 elements
print(numbers[2:])    # [3, 4, 5] - from index 2 to end

# List operations
combined = fruits + ["grape", "kiwi"]  # Concatenation
repeated = [1, 2] * 3                  # Repetition: [1, 2, 1, 2, 1, 2]

# %% [markdown]
# #### 1.5.2 元组 (Tuples) —— 不可变有序集合
# 元组是有序的，但在创建后无法修改。你可以将其视为列表的只读版本。

# %%
# Creating tuples
colors = ("red", "green", "blue")
single_item = ("only",)  # Note the comma for single-item tuple
coordinates = (10, 20)

# Accessing elements (same as lists)
print(colors[0])     # "red"
print(colors[-1])    # "blue"

# Tuples are immutable - this would cause an error:
# colors[0] = "yellow"  # TypeError!

# %% [markdown]
# #### 1.5.3 字典 (Dictionaries) —— 键值对
# 字典以键:值对的方式存储数据。字典是无序的（Python 3.7+ 起变更为插入有序）。由于它是基于[哈希表 (hash table)](https://en.wikipedia.org/wiki/Hash_table) 实现的，通过键查找值的时间复杂度仅为 $O(1)$（当然，前提是哈希分布良好且冲突较少）。

# %%
# Creating dictionaries
person = {"name": "Alice", "age": 30, "city": "New York"}
scores = dict(math=95, science=88, history=92)  # Alternative syntax

# Accessing values
print(person["name"])        # "Alice"
print(person.get("age"))     # 30
print(person.get("email", "Not provided"))  # Default if key doesn't exist

# Modifying dictionaries
person["email"] = "alice@email.com"  # Add new key-value
person["age"] = 31                    # Update value
del person["city"]                    # Remove key
removed = person.pop("age")           # Remove and return value

# Dictionary methods
keys = person.keys()      # Get all keys
values = person.values()  # Get all values
items = person.items()    # Get all (key, value) pairs

# Looping through dictionaries
for key in person:
    print(key, person[key])

for key, value in person.items():
    print(f"{key}: {value}")

# %% [markdown]
# #### 1.5.4 集合 (Sets) —— 无序唯一集合
# 集合存储唯一的元素，是无序的，并支持数学集合运算。由于同样基于哈希表实现，在集合中查找元素的时间复杂度也是 $O(1)$。

# %%
# Creating sets
primes = {2, 3, 5, 7, 11}
even_numbers = set([2, 4, 6, 8, 10])  # Using set() constructor

# Sets automatically remove duplicates
colors = {"red", "green", "blue", "red", "green"}
print(colors)  # {'red', 'green', 'blue'}

# Set operations
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

print(A | B)   # Union: {1, 2, 3, 4, 5, 6, 7, 8}
print(A & B)   # Intersection: {4, 5}
print(A - B)   # Difference (in A but not B): {1, 2, 3}
print(A ^ B)   # Symmetric difference (in A or B but not both): {1, 2, 3, 6, 7, 8}

# Set methods
primes.add(13)          # Add element
primes.remove(2)        # Remove element (error if not exists)
primes.discard(100)     # Remove if exists (no error if not)
element = primes.pop()  # Remove and return arbitrary element
print(element, primes)

# %% [markdown]
# #### 1.5.5 容器通用操作
# 所有容器都共有一些基本操作：

# %%
# Checking membership
fruits = ["apple", "banana", "cherry"]
print("apple" in fruits)     # True
print("grape" not in fruits) # True

# Length of container
print(len(fruits))           # 3

# Looping through any container
for fruit in fruits:
    print(fruit, end=" ")

# Converting between containers
my_list = [1, 2, 3, 2]
my_set = set(my_list)        # {1, 2, 3} - removes duplicates
my_tuple = tuple(my_list)    # (1, 2, 3, 2)
print(my_list)
print(my_set)
print(my_tuple)

# %% [markdown]
# #### 1.5.6 推导式 (Comprehensions)
# 推导式是结合循环或条件来编写容器的一种捷径。Python 为列表、字典和集合都提供了推导式支持。

# %%
# Basic comprehension
squares = [x**2 for x in range(10)]  # [0, 1, 4, 9, ..., 81]
print(squares)

# With condition
even_squares = [x**2 for x in range(10) if x % 2 == 0]
print(even_squares)

# Dictionary comprehension
square_dict = {x: x**2 for x in range(5)}  # {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
print(square_dict)

# Set comprehension
unique_lengths = {len(word) for word in ["hello", "world", "python"]}
print(unique_lengths)

# %% [markdown]
# ### 1.6 **Python 中的函数**

# %% [markdown]
# #### 1.6.1 函数基础语法

# %% [markdown]
# 在 Python 中，你可以使用 `def` 关键字定义自己的函数：

# %%
# Simple function
def greet():
    print("Hello, World!")

greet()

# Function with parameters
def greet_person(name):
    print(f"Hello, {name}!")
    
greet_person("SSTIA")

# Function with return value
def add(a, b):
    return a + b

print(add(2,3))

# Function with default parameters
def greet_with_time(name, time="morning"):
    print(f"Good {time}, {name}!")

greet_with_time("SSTIA")

# Function with docstring
def multiply(a, b):
    """Calculates the multiplication of two numbers.

    Args:
        a (int/float): a factor.
        b (int/float): another factor.

    Returns:
        int/float: The product.
    """
    return a * b

# %% [markdown]
# 在 Python 中，传入参数的顺序很重要，但也可以显式更改：

# %%
def describe_pet(animal_type, pet_name):
    print(f"I have a {animal_type} named {pet_name}.")


describe_pet("hamster", "Harry")  # Order matters
describe_pet("Harry", "hamster")  # This is wrong
describe_pet(pet_name="Harry", animal_type="hamster")  # Order can be changed using keyword arguments

# %% [markdown]
# #### 1.6.2 *args 与 **kwargs

# %% [markdown]
# `*` 在 Python 中意味着“解包 (unpacking)”。它允许展开列表或元组中的元素。`*args` 用于接收任意数量的位置参数。例如，`*my_list` 表示展开名为 `my_list` 的列表。通过它，我们可以定义参数数量可变的函数。

# %%
def make_pizza(*toppings):
    print("Making pizza with:")
    for topping in toppings:
        print(f"- {topping}")


make_pizza('mushrooms', 'peppers', 'cheese')
make_pizza('cheese')  # Works with any number

# %% [markdown]
# 类似地，`**` 允许展开字典中的元素。`**kwargs` 表示接收任意数量的关键字参数。

# %%
def build_profile(first, last, **user_info):
    profile = {'first_name': first, 'last_name': last}
    for key, value in user_info.items():
        profile[key] = value
    return profile


user_profile = build_profile('John', 'Doe', age=30, city='NYC', job='Engineer')
for key, value in user_profile.items():
    print(f"{key}: {value}")

# %% [markdown]
# `*args` 和 `**kwargs` 对于编写高灵活性的函数至关重要。让我们通过一个简单的练习，利用 `*args` 构建一个日志记录器。

# %%
def log_message(level, *messages):
    """Log multiple message parts"""
    full_message =  ## TODO: use "join" to connect multiple strings
    ## TODO: print the message with level and message in expected format


connection_time = 100
log_message("error", "Failed to connect to database:", f"Connection timeout {connection_time}ms elapsed")
# Output: [ERROR] Failed to connect to database: Connection timeout

# %% [markdown]
# #### 1.6.3 生命周期 (Lifetime)

# %% [markdown]
# 函数内部变量的生命周期与没有作用域定义的变量不同（在 Python 中，`if` 和 `while` 不构成独立作用域）。首先，让我们了解如何通过 `global` 关键字在函数内部访问和修改全局变量。

# %%
x = 10  # Global variable

def func1():
    x = 20  # This creates a new LOCAL variable
    print("Inside func1:", x)  # 20


func1()
print("Outside:", x)  # 10 (global unchanged)


def func2():
    global x  # Declare we're using the global x
    x = 20  # Modifies the global variable
    print("Inside func2:", x)  # 20


func2()
print("Outside:", x)  # 20 (global changed!)


def func3():
    # You can access the global variable without "global" keyword, but you can not modify it
    print("Inside func3:", x)


func3()

# %% [markdown]
# #### 1.6.4 [可选] Lambda 表达式

# %% [markdown]
# Lambda 函数即匿名函数。在 Python 中，可以使用 `lambda` 关键字创建。基本语法为 `lambda arguments: expression`。Lambda 在函数式编程风格中非常重要。

# %%
# Regular function
def add(x, y):
    return x + y


# Lambda equivalent
add_lambda = lambda x, y: x + y

print(add(3, 5))  # 8
print(add_lambda(3, 5))  # 8

# %%
# Returns different values based on condition
grade_status = lambda score: "Pass" if score >= 60 else "Fail"
print(grade_status(75))  # returns "Pass"
print(grade_status(45))  # returns "Fail"

# Nested conditional (ternary)
classify = lambda x: (
    "positive" if x > 0 else
    "negative" if x < 0 else 
    "zero"
)

print(classify(5))  # returns "positive"
print(classify(-2))  # returns "negative"
print(classify(0))  # returns "zero"

# %% [markdown]
# #### 1.6.5 [可选] 生成器 (Generators)

# %% [markdown]
# 生成器函数允许保存函数状态，并仅返回 `yield` 出的单个值。一旦某个值被产出 (yielded)，函数会在此处暂停，直到下一次被调用。

# %%
def count_up_to(max):
    print("Generator Run")
    count = 1
    while count <= max:
        yield count  # Yields value, then pauses.
        print("Yield called")
        count += 1


counter = count_up_to(5)

print(next(counter))
print(next(counter), end="\n\n")

for num in counter:
    print(num)

# %% [markdown]
# #### 1.6.6 [可选] 装饰器 (Decorators)

# %% [markdown]
# 装饰器是一个可调用对象（通常是函数或类），它：
#
# - 接受一个函数作为参数
#
# - 返回一个（通常是经过修改或包装的）新函数
#
# 装饰器利用了“函数指针”的概念。当你编写以下代码时：
#
# ```python
# @decorator
# def my_func():
#     pass
# ```
# 它等同于：
#
# ```python
# def my_func():
#     pass
# my_func = decorator(my_func)  # 将函数作为参数传递
# ```

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print(f"Calling '{func.__name__}{args}': ")
        return func(*args, **kwargs)
    return wrapper  # Returns a new "function pointer"


@logger  # this line is equiivalent to: add = logger(add), so now add is pointing to wrapper
def add(a, b):
    return a + b


# add is now pointing to wrapper, which internally calls the original add
print(add(2, 3))  # Prints: "Calling add" then 5

# %% [markdown]
# 装饰器可以在保持原函数不变的情况下，为其添加新功能（如日志记录、计时等）。让我们制作一个计时器，用来统计函数的运行时间：

# %%
def timer_decorator(func):
    def wrapper(*args, **kwargs):
        ## TODO: Write a timer with decorators
    return wrapper

@timer_decorator
def slow_function(n):
    time.sleep(n)

slow_function(2)
